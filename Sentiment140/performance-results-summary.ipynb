# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# %cd '/content/gdrive/My Drive/new results'
# Out:
# /content/gdrive/My Drive/new results

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
##123, size= 320
#nat_df1 = pd.read_csv("new3-1_1-f1_1.csv")

# %% [markdown]
# ###getting mean values of evaluation metrics for 30 rounds of samples

# %%
import seaborn as sns
all_df = pd.DataFrame()
mat = np.zeros((25,8))
for i in range(30):
  filename = "za-new3-1_"+str(i+1)+"-accuracy.csv"
  nat_df1 = pd.read_csv(filename)
  nat_df1 = nat_df1.drop(nat_df1.columns[0], axis = 1) #drop the column of index
  m = nat_df1.to_numpy()
  #print(m)
  mat = mat + m
  #print(mat)

fin_df = pd.DataFrame(mat/30, columns = nat_df1.columns)
fin_df.to_csv("za-mean-30-accuracy.csv")
fin_df.describe()
  #ax = sns.heatmap(nat_df1.corr(), annot=True)
  #ax.set(title = str(i+1))
  #fig = ax.get_figure()
  #plt.show()
  #print(nat_df1.describe())
# Out:
#         baseline    5-mixed         CA         AU         NZ         UK  \
# count  25.000000  25.000000  25.000000  25.000000  25.000000  25.000000
# mean    0.843200   0.821253   0.825313   0.814300   0.799873   0.814300
# std     0.027984   0.004760   0.007021   0.006055   0.009436   0.005216
# min     0.780000   0.811333   0.809667   0.802167   0.779833   0.804500
# 25%     0.820000   0.818000   0.820833   0.811833   0.794167   0.810500
# 50%     0.845000   0.820833   0.826333   0.815167   0.798667   0.813333
# 75%     0.860000   0.825167   0.829333   0.818667   0.808500   0.817833
# max     0.900000   0.829833   0.838833   0.825667   0.812833   0.825167
#
#               US         ZA
# count  25.000000  25.000000
# mean    0.824740   0.838473
# std     0.004485   0.009207
# min     0.816500   0.824000
# 25%     0.821333   0.832833
# 50%     0.824667   0.836667
# 75%     0.827500   0.840500
# max     0.833333   0.856667

# %%
import seaborn as sns
from scipy.spatial.distance import correlation
all_df = pd.DataFrame()
mat = np.zeros((25,8))
for i in range(30):
  filename = "za-new3-1_"+str(i+1)+"-f1_1.csv"
  nat_df1 = pd.read_csv(filename)
  nat_df1 = nat_df1.drop(nat_df1.columns[0], axis = 1) #drop the column of index
  m = nat_df1.to_numpy()
  #print(m)
  mat = mat + m
  #print(mat)

#print("ZA-mixed:",correlation(mat[:,7],mat[:,1])
#)

fin_df = pd.DataFrame(mat/30, columns = nat_df1.columns)
fin_df.to_csv("za-mean-30-f1_1.csv")
fin_df.describe()
  #ax = sns.heatmap(nat_df1.corr(), annot=True)
  #ax.set(title = str(i+1))
  #fig = ax.get_figure()
  #plt.show()
  #print(nat_df1.describe())
# Out:
#         baseline    5-mixed         CA         AU         NZ         UK  \
# count  25.000000  25.000000  25.000000  25.000000  25.000000  25.000000
# mean    0.840309   0.817853   0.822347   0.820425   0.822215   0.801070
# std     0.026861   0.004774   0.007353   0.007354   0.010080   0.006107
# min     0.778443   0.807192   0.806925   0.804315   0.801704   0.790036
# 25%     0.826923   0.814984   0.818204   0.815235   0.816078   0.797593
# 50%     0.843243   0.817679   0.822827   0.821106   0.822765   0.801406
# 75%     0.853659   0.820982   0.827309   0.826383   0.830986   0.804557
# max     0.894737   0.826994   0.837143   0.833951   0.836761   0.814862
#
#               US         ZA
# count  25.000000  25.000000
# mean    0.820262   0.851682
# std     0.005608   0.009621
# min     0.808722   0.834504
# 25%     0.816443   0.844652
# 50%     0.821290   0.851505
# 75%     0.822669   0.856101
# max     0.832118   0.870212

# %%
import seaborn as sns
import pandas as pd
import numpy as np
all_df = pd.DataFrame()
mat = np.zeros((25,8))
for i in range(30):
  filename = "za-new3-1_"+str(i+1)+"-f1_0.csv"
  nat_df1 = pd.read_csv(filename)
  nat_df1 = nat_df1.drop(nat_df1.columns[0], axis = 1) #drop the column of index
  m = nat_df1.to_numpy()
  #print(m)
  mat = mat + m
  #print(mat)

fin_df = pd.DataFrame(mat/30, columns = nat_df1.columns)
fin_df.to_csv("za-mean-30-f1_0.csv")
fin_df.describe()
  #ax = sns.heatmap(nat_df1.corr(), annot=True)
  #ax.set(title = str(i+1))
  #fig = ax.get_figure()
  #plt.show()
  #print(nat_df1.describe())
# Out:
#         baseline    5-mixed         CA         AU         NZ         UK  \
# count  25.000000  25.000000  25.000000  25.000000  25.000000  25.000000
# mean    0.844290   0.822783   0.827030   0.806488   0.770102   0.824951
# std     0.034338   0.006374   0.008053   0.006322   0.009219   0.006348
# min     0.752809   0.812615   0.808718   0.793635   0.751663   0.813434
# 25%     0.831776   0.816082   0.821986   0.800862   0.765650   0.819760
# 50%     0.841584   0.822768   0.828306   0.808106   0.770607   0.825156
# 75%     0.867925   0.828626   0.832902   0.811072   0.776145   0.829713
# max     0.904762   0.831278   0.839484   0.815641   0.787350   0.835421
#
#               US         ZA
# count  25.000000  25.000000
# mean    0.827597   0.822204
# std     0.005040   0.008939
# min     0.817637   0.809086
# 25%     0.824110   0.816853
# 50%     0.826776   0.820296
# 75%     0.831485   0.826685
# max     0.836093   0.840706

# %%
import seaborn as sns
import pandas as pd
import numpy as np
all_df = pd.DataFrame()
mat = np.zeros((25,8))
for i in range(30):
  filename = "za-new3-1_"+str(i+1)+"-auc.csv"
  nat_df1 = pd.read_csv(filename)
  nat_df1 = nat_df1.drop(nat_df1.columns[0], axis = 1) #drop the column of index
  m = nat_df1.to_numpy()
  #print(m)
  mat = mat + m
  #print(mat)

fin_df = pd.DataFrame(mat/30, columns = nat_df1.columns)
fin_df.to_csv("za-mean-30-auc.csv")
fin_df.describe()
# Out:
#         baseline    5-mixed         CA         AU         NZ         UK  \
# count  25.000000  25.000000  25.000000  25.000000  25.000000  25.000000
# mean    0.918352   0.901218   0.909848   0.896113   0.884294   0.897208
# std     0.019421   0.003772   0.004920   0.004817   0.005137   0.004842
# min     0.877576   0.894148   0.901364   0.887188   0.876340   0.887706
# 25%     0.905500   0.898502   0.907119   0.893381   0.881183   0.894692
# 50%     0.922521   0.901951   0.910490   0.896112   0.883930   0.897839
# 75%     0.926934   0.904644   0.913624   0.899728   0.885870   0.901168
# max     0.954227   0.906110   0.917601   0.904152   0.896813   0.904707
#
#               US         ZA
# count  25.000000  25.000000
# mean    0.907652   0.922289
# std     0.003913   0.007609
# min     0.900427   0.907664
# 25%     0.905332   0.916293
# 50%     0.909277   0.923279
# 75%     0.910742   0.927879
# max     0.912341   0.935905

# %%
import seaborn as sns
import pandas as pd
import numpy as np
all_df = pd.DataFrame()
mat = np.zeros((25,8))
for i in range(30):
  filename = "za-new3-1_"+str(i+1)+"-precision_0.csv"
  nat_df1 = pd.read_csv(filename)
  nat_df1 = nat_df1.drop(nat_df1.columns[0], axis = 1) #drop the column of index
  m = nat_df1.to_numpy()
  #print(m)
  mat = mat + m
  #print(mat)

fin_df = pd.DataFrame(mat/30, columns = nat_df1.columns)
fin_df.to_csv("za-mean-30-precision0.csv")
fin_df.describe()
# Out:
#         baseline    5-mixed         CA         AU         NZ         UK  \
# count  25.000000  25.000000  25.000000  25.000000  25.000000  25.000000
# mean    0.838148   0.821893   0.834048   0.797491   0.735223   0.819040
# std     0.042758   0.010294   0.012807   0.014470   0.016743   0.011261
# min     0.761364   0.806773   0.808670   0.770809   0.708222   0.802655
# 25%     0.809091   0.813383   0.825325   0.785913   0.724630   0.810843
# 50%     0.831579   0.820570   0.833478   0.794866   0.731446   0.815651
# 75%     0.861111   0.826854   0.844045   0.806460   0.745636   0.824709
# max     0.921739   0.845750   0.860369   0.828680   0.763359   0.844207
#
#               US         ZA
# count  25.000000  25.000000
# mean    0.819749   0.800581
# std     0.011165   0.016234
# min     0.801400   0.768649
# 25%     0.810822   0.793438
# 50%     0.818223   0.800632
# 75%     0.826814   0.808406
# max     0.841975   0.832146

# %%
import seaborn as sns
import pandas as pd
import numpy as np
all_df = pd.DataFrame()
mat = np.zeros((25,8))
for i in range(30):
  filename = "za-new3-1_"+str(i+1)+"-precision_1.csv"
  nat_df1 = pd.read_csv(filename)
  nat_df1 = nat_df1.drop(nat_df1.columns[0], axis = 1) #drop the column of index
  m = nat_df1.to_numpy()
  #print(m)
  mat = mat + m
  #print(mat)

fin_df = pd.DataFrame(mat/30, columns = nat_df1.columns)
fin_df.to_csv("za-mean-30-precision1.csv")
fin_df.describe()
# Out:
#         baseline    5-mixed         CA         AU         NZ         UK  \
# count  25.000000  25.000000  25.000000  25.000000  25.000000  25.000000
# mean    0.848579   0.821415   0.817667   0.831686   0.854971   0.811324
# std     0.037675   0.013149   0.014170   0.011271   0.009911   0.014217
# min     0.763636   0.793439   0.784858   0.811692   0.840632   0.779446
# 25%     0.823529   0.813672   0.806665   0.825361   0.847642   0.804987
# 50%     0.858586   0.820842   0.821569   0.832514   0.853574   0.814791
# 75%     0.876190   0.831581   0.829025   0.841235   0.862534   0.821079
# max     0.904255   0.840125   0.835962   0.851488   0.873247   0.833277
#
#               US         ZA
# count  25.000000  25.000000
# mean    0.830960   0.872123
# std     0.011587   0.008271
# min     0.809682   0.856770
# 25%     0.822346   0.868015
# 50%     0.833395   0.872962
# 75%     0.838349   0.877213
# max     0.852632   0.885666

# %%
import seaborn as sns
import pandas as pd
import numpy as np
all_df = pd.DataFrame()
mat = np.zeros((25,8))
for i in range(30):
  filename = "za-new3-1_"+str(i+1)+"-recall_0.csv"
  nat_df1 = pd.read_csv(filename)
  nat_df1 = nat_df1.drop(nat_df1.columns[0], axis = 1) #drop the column of index
  m = nat_df1.to_numpy()
  #print(m)
  mat = mat + m
  #print(mat)

fin_df = pd.DataFrame(mat/30, columns = nat_df1.columns)
fin_df.to_csv("za-mean-30-recall0.csv")
fin_df.describe()
# Out:
#         baseline    5-mixed         CA         AU         NZ         UK  \
# count  25.000000  25.000000  25.000000  25.000000  25.000000  25.000000
# mean    0.852259   0.825608   0.821779   0.817780   0.810071   0.833492
# std     0.044689   0.018644   0.019742   0.018156   0.017683   0.019150
# min     0.740000   0.783440   0.775850   0.782254   0.778548   0.786538
# 25%     0.842697   0.817526   0.805285   0.805168   0.795749   0.825937
# 50%     0.859813   0.826323   0.828728   0.819547   0.811884   0.836127
# 75%     0.877778   0.841930   0.837028   0.831544   0.822030   0.848059
# max     0.913462   0.851489   0.846189   0.847330   0.837334   0.859958
#
#               US         ZA
# count  25.000000  25.000000
# mean    0.837129   0.872123
# std     0.016294   0.008271
# min     0.804027   0.856770
# 25%     0.827541   0.868015
# 50%     0.838314   0.872962
# 75%     0.848506   0.877213
# max     0.864866   0.885666

# %%
import seaborn as sns
import pandas as pd
import numpy as np
all_df = pd.DataFrame()
mat = np.zeros((25,8))
for i in range(30):
  filename = "za-new3-1_"+str(i+1)+"-recall_1.csv"
  nat_df1 = pd.read_csv(filename)
  nat_df1 = nat_df1.drop(nat_df1.columns[0], axis = 1) #drop the column of index
  m = nat_df1.to_numpy()
  #print(m)
  mat = mat + m
  #print(mat)

fin_df = pd.DataFrame(mat/30, columns = nat_df1.columns)
fin_df.to_csv("za-mean-30-recall1.csv")
fin_df.describe()
# Out:
#         baseline    5-mixed         CA         AU         NZ         UK  \
# count  25.000000  25.000000  25.000000  25.000000  25.000000  25.000000
# mean    0.834136   0.816238   0.828786   0.811282   0.792895   0.794229
# std     0.040660   0.015906   0.018396   0.019603   0.019975   0.019136
# min     0.714286   0.793550   0.793155   0.776648   0.762537   0.768135
# 25%     0.814433   0.802782   0.815624   0.794580   0.779462   0.780856
# 50%     0.836364   0.814833   0.828279   0.806789   0.788304   0.791111
# 75%     0.854545   0.826769   0.842724   0.822608   0.805535   0.806568
# max     0.913043   0.853500   0.866382   0.851780   0.829032   0.838349
#
#               US         ZA
# count  25.000000  25.000000
# mean    0.811539   0.872123
# std     0.017009   0.008271
# min     0.786171   0.856770
# 25%     0.797543   0.868015
# 50%     0.808172   0.872962
# 75%     0.821219   0.877213
# max     0.845296   0.885666

# %% [markdown]
# ###Geting distance correlation results for performance evaluation metrics

# %%
# !pip install dcor
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 1.6 MB/s eta 0:00:00
# ...

# %%
#import dcor
from dcor import distance_correlation

# %% [markdown]
# precision (negative label prediction)

# %%
import seaborn as sns
from scipy.spatial.distance import correlation
all_df = pd.DataFrame()
mat = np.zeros((25,8))
for i in range(30):
  filename = "za-new3-1_"+str(i+1)+"-precision_0.csv"
  nat_df1 = pd.read_csv(filename)
  nat_df1 = nat_df1.drop(nat_df1.columns[0], axis = 1) #drop the column of index
  m = nat_df1.to_numpy()
  #print(m)
  mat = mat + m
  #print(mat)

mat = mat/30
print("ZA-mixed:",distance_correlation(mat[:,7],mat[:,1]))
print("ZA-CA:",distance_correlation(mat[:,7],mat[:,2]))
print("ZA-AU:",distance_correlation(mat[:,7],mat[:,3]))
print("ZA-NZ:",distance_correlation(mat[:,7],mat[:,4]))
print("ZA-UK:",distance_correlation(mat[:,7],mat[:,5]))
print("ZA-US:",distance_correlation(mat[:,7],mat[:,6]))
print("mixed-CA:",distance_correlation(mat[:,1],mat[:,2]))
print("mixed-AU:",distance_correlation(mat[:,1],mat[:,3]))
print("mixed-NZ:",distance_correlation(mat[:,1],mat[:,4]))
print("mixed-UK:",distance_correlation(mat[:,1],mat[:,5]))
print("mixed-US:",distance_correlation(mat[:,1],mat[:,6]))
print("CA-AU:",distance_correlation(mat[:,2],mat[:,3]))
print("CA-NZ:",distance_correlation(mat[:,2],mat[:,4]))
print("CA-UK:",distance_correlation(mat[:,2],mat[:,5]))
print("CA-US:",distance_correlation(mat[:,2],mat[:,6]))
print("AU-NZ:",distance_correlation(mat[:,3],mat[:,4]))
print("AU-UK:",distance_correlation(mat[:,3],mat[:,5]))
print("AU-US:",distance_correlation(mat[:,3],mat[:,6]))
print("NZ-UK:",distance_correlation(mat[:,4],mat[:,5]))
print("NZ-US:",distance_correlation(mat[:,4],mat[:,6]))
print("UK-US:",distance_correlation(mat[:,5],mat[:,6]))
# Out:
# ZA-mixed: 0.6171789712308424
# ZA-CA: 0.6428939414606412
# ZA-AU: 0.6494566063354913
# ZA-NZ: 0.4131751810725987
# ZA-UK: 0.5479565314103967
# ZA-US: 0.5791520172330723
# mixed-CA: 0.8832755410189103
# mixed-AU: 0.9090156245793584
# mixed-NZ: 0.6324514964958006
# mixed-UK: 0.9341849703089117
# mixed-US: 0.8922907353016455
# CA-AU: 0.8473981607691773
# CA-NZ: 0.48620321111989606
# CA-UK: 0.9000838633908644
# CA-US: 0.8551093777840403
# AU-NZ: 0.5949957656306518
# AU-UK: 0.8936473135258521
# AU-US: 0.9016079857911301
# NZ-UK: 0.5601289101668839
# NZ-US: 0.5910702148658111
# UK-US: 0.9338228175322687

# %%
print("base-mixed:",distance_correlation(mat[:,0],mat[:,1]))
print("base-CA:",distance_correlation(mat[:,0],mat[:,2]))
print("base-AU:",distance_correlation(mat[:,0],mat[:,3]))
print("base-NZ:",distance_correlation(mat[:,0],mat[:,4]))
print("base-UK:",distance_correlation(mat[:,0],mat[:,5]))
print("base-US",distance_correlation(mat[:,0],mat[:,6]))
print("base-ZA:",distance_correlation(mat[:,0],mat[:,7]))
# Out:
# base-mixed: 0.31381599059294235
# base-CA: 0.2829249167037693
# base-AU: 0.27425569166188
# base-NZ: 0.3166364545112655
# base-UK: 0.27793419425312954
# base-US 0.27075072082521107
# base-ZA: 0.33345796336429456

# %% [markdown]
# precision (positive label prediction)

# %%
import seaborn as sns
from scipy.spatial.distance import correlation
all_df = pd.DataFrame()
mat = np.zeros((25,8))
for i in range(30):
  filename = "za-new3-1_"+str(i+1)+"-precision_1.csv"
  nat_df1 = pd.read_csv(filename)
  nat_df1 = nat_df1.drop(nat_df1.columns[0], axis = 1) #drop the column of index
  m = nat_df1.to_numpy()
  #print(m)
  mat = mat + m
  #print(mat)

mat = mat/30
print("ZA-mixed:",distance_correlation(mat[:,7],mat[:,1]))
print("ZA-CA:",distance_correlation(mat[:,7],mat[:,2]))
print("ZA-AU:",distance_correlation(mat[:,7],mat[:,3]))
print("ZA-NZ:",distance_correlation(mat[:,7],mat[:,4]))
print("ZA-UK:",distance_correlation(mat[:,7],mat[:,5]))
print("ZA-US:",distance_correlation(mat[:,7],mat[:,6]))
print("mixed-CA:",distance_correlation(mat[:,1],mat[:,2]))
print("mixed-AU:",distance_correlation(mat[:,1],mat[:,3]))
print("mixed-NZ:",distance_correlation(mat[:,1],mat[:,4]))
print("mixed-UK:",distance_correlation(mat[:,1],mat[:,5]))
print("mixed-US:",distance_correlation(mat[:,1],mat[:,6]))
print("CA-AU:",distance_correlation(mat[:,2],mat[:,3]))
print("CA-NZ:",distance_correlation(mat[:,2],mat[:,4]))
print("CA-UK:",distance_correlation(mat[:,2],mat[:,5]))
print("CA-US:",distance_correlation(mat[:,2],mat[:,6]))
print("AU-NZ:",distance_correlation(mat[:,3],mat[:,4]))
print("AU-UK:",distance_correlation(mat[:,3],mat[:,5]))
print("AU-US:",distance_correlation(mat[:,3],mat[:,6]))
print("NZ-UK:",distance_correlation(mat[:,4],mat[:,5]))
print("NZ-US:",distance_correlation(mat[:,4],mat[:,6]))
print("UK-US:",distance_correlation(mat[:,5],mat[:,6]))
# Out:
# ZA-mixed: 0.5127196393486063
# ZA-CA: 0.5586886876206347
# ZA-AU: 0.46793664908485894
# ZA-NZ: 0.465517816925794
# ZA-UK: 0.5998334579788233
# ZA-US: 0.5519463849228246
# mixed-CA: 0.9044886276508224
# mixed-AU: 0.9063315856239555
# mixed-NZ: 0.6170587088656229
# mixed-UK: 0.9443433430072717
# mixed-US: 0.9383413526946481
# CA-AU: 0.8682873168065118
# CA-NZ: 0.6357995271783518
# CA-UK: 0.8341321855087508
# CA-US: 0.9107093938842652
# AU-NZ: 0.6497061338675175
# AU-UK: 0.8656416523731352
# AU-US: 0.8836733675756411
# NZ-UK: 0.5825322890228488
# NZ-US: 0.6597666134865421
# UK-US: 0.8729363979445588

# %%
print("base-mixed:",distance_correlation(mat[:,0],mat[:,1]))
print("base-CA:",distance_correlation(mat[:,0],mat[:,2]))
print("base-AU:",distance_correlation(mat[:,0],mat[:,3]))
print("base-NZ:",distance_correlation(mat[:,0],mat[:,4]))
print("base-UK:",distance_correlation(mat[:,0],mat[:,5]))
print("base-US",distance_correlation(mat[:,0],mat[:,6]))
print("base-ZA:",distance_correlation(mat[:,0],mat[:,7]))
# Out:
# base-mixed: 0.5498278509776445
# base-CA: 0.5770919031011509
# base-AU: 0.5726168627378906
# base-NZ: 0.5065786268996505
# base-UK: 0.5359904112980798
# base-US 0.5771280574711964
# base-ZA: 0.32841873837803415

# %% [markdown]
# recall (negative label prediction)

# %%
import seaborn as sns
from scipy.spatial.distance import correlation
all_df = pd.DataFrame()
mat = np.zeros((25,8))
for i in range(30):
  filename = "za-new3-1_"+str(i+1)+"-recall_0.csv"
  nat_df1 = pd.read_csv(filename)
  nat_df1 = nat_df1.drop(nat_df1.columns[0], axis = 1) #drop the column of index
  m = nat_df1.to_numpy()
  #print(m)
  mat = mat + m
  #print(mat)

mat = mat/30
print("ZA-mixed:",distance_correlation(mat[:,7],mat[:,1]))
print("ZA-CA:",distance_correlation(mat[:,7],mat[:,2]))
print("ZA-AU:",distance_correlation(mat[:,7],mat[:,3]))
print("ZA-NZ:",distance_correlation(mat[:,7],mat[:,4]))
print("ZA-UK:",distance_correlation(mat[:,7],mat[:,5]))
print("ZA-US:",distance_correlation(mat[:,7],mat[:,6]))
print("mixed-CA:",distance_correlation(mat[:,1],mat[:,2]))
print("mixed-AU:",distance_correlation(mat[:,1],mat[:,3]))
print("mixed-NZ:",distance_correlation(mat[:,1],mat[:,4]))
print("mixed-UK:",distance_correlation(mat[:,1],mat[:,5]))
print("mixed-US:",distance_correlation(mat[:,1],mat[:,6]))
print("CA-AU:",distance_correlation(mat[:,2],mat[:,3]))
print("CA-NZ:",distance_correlation(mat[:,2],mat[:,4]))
print("CA-UK:",distance_correlation(mat[:,2],mat[:,5]))
print("CA-US:",distance_correlation(mat[:,2],mat[:,6]))
print("AU-NZ:",distance_correlation(mat[:,3],mat[:,4]))
print("AU-UK:",distance_correlation(mat[:,3],mat[:,5]))
print("AU-US:",distance_correlation(mat[:,3],mat[:,6]))
print("NZ-UK:",distance_correlation(mat[:,4],mat[:,5]))
print("NZ-US:",distance_correlation(mat[:,4],mat[:,6]))
print("UK-US:",distance_correlation(mat[:,5],mat[:,6]))
# Out:
# ZA-mixed: 0.5400491413550735
# ZA-CA: 0.5682080855943884
# ZA-AU: 0.48016115137882537
# ZA-NZ: 0.523959235688214
# ZA-UK: 0.6197483920356882
# ZA-US: 0.5813784484826162
# mixed-CA: 0.9363353935725083
# mixed-AU: 0.9267246505275938
# mixed-NZ: 0.754702613690456
# mixed-UK: 0.9607700752327009
# mixed-US: 0.9619306333280162
# CA-AU: 0.9016501004951704
# CA-NZ: 0.7754839681350224
# CA-UK: 0.880256865162651
# CA-US: 0.9430915617608618
# AU-NZ: 0.7699665106737373
# AU-UK: 0.8903297177600913
# AU-US: 0.9103925479757611
# NZ-UK: 0.7386178058509717
# NZ-US: 0.7946196643198684
# UK-US: 0.9193689181567006

# %%
print("base-mixed:",distance_correlation(mat[:,0],mat[:,1]))
print("base-CA:",distance_correlation(mat[:,0],mat[:,2]))
print("base-AU:",distance_correlation(mat[:,0],mat[:,3]))
print("base-NZ:",distance_correlation(mat[:,0],mat[:,4]))
print("base-UK:",distance_correlation(mat[:,0],mat[:,5]))
print("base-US",distance_correlation(mat[:,0],mat[:,6]))
print("base-ZA:",distance_correlation(mat[:,0],mat[:,7]))
# Out:
# base-mixed: 0.6094764373823119
# base-CA: 0.6175896977900143
# base-AU: 0.6002066144690662
# base-NZ: 0.6058301748647368
# base-UK: 0.6712159666733605
# base-US 0.6318624043649728
# base-ZA: 0.386770556651742

# %% [markdown]
# recall (positive label prediction)

# %%
import seaborn as sns
from scipy.spatial.distance import correlation
all_df = pd.DataFrame()
mat = np.zeros((25,8))
for i in range(30):
  filename = "za-new3-1_"+str(i+1)+"-recall_1.csv"
  nat_df1 = pd.read_csv(filename)
  nat_df1 = nat_df1.drop(nat_df1.columns[0], axis = 1) #drop the column of index
  m = nat_df1.to_numpy()
  #print(m)
  mat = mat + m
  #print(mat)

mat = mat/30
print("ZA-mixed:",distance_correlation(mat[:,7],mat[:,1]))
print("ZA-CA:",distance_correlation(mat[:,7],mat[:,2]))
print("ZA-AU:",distance_correlation(mat[:,7],mat[:,3]))
print("ZA-NZ:",distance_correlation(mat[:,7],mat[:,4]))
print("ZA-UK:",distance_correlation(mat[:,7],mat[:,5]))
print("ZA-US:",distance_correlation(mat[:,7],mat[:,6]))
print("mixed-CA:",distance_correlation(mat[:,1],mat[:,2]))
print("mixed-AU:",distance_correlation(mat[:,1],mat[:,3]))
print("mixed-NZ:",distance_correlation(mat[:,1],mat[:,4]))
print("mixed-UK:",distance_correlation(mat[:,1],mat[:,5]))
print("mixed-US:",distance_correlation(mat[:,1],mat[:,6]))
print("CA-AU:",distance_correlation(mat[:,2],mat[:,3]))
print("CA-NZ:",distance_correlation(mat[:,2],mat[:,4]))
print("CA-UK:",distance_correlation(mat[:,2],mat[:,5]))
print("CA-US:",distance_correlation(mat[:,2],mat[:,6]))
print("AU-NZ:",distance_correlation(mat[:,3],mat[:,4]))
print("AU-UK:",distance_correlation(mat[:,3],mat[:,5]))
print("AU-US:",distance_correlation(mat[:,3],mat[:,6]))
print("NZ-UK:",distance_correlation(mat[:,4],mat[:,5]))
print("NZ-US:",distance_correlation(mat[:,4],mat[:,6]))
print("UK-US:",distance_correlation(mat[:,5],mat[:,6]))
# Out:
# ZA-mixed: 0.5415254654219763
# ZA-CA: 0.4849718549400932
# ZA-AU: 0.4731997537482942
# ZA-NZ: 0.5386826397475458
# ZA-UK: 0.5596002964026593
# ZA-US: 0.5577484795756451
# mixed-CA: 0.9174642778482407
# mixed-AU: 0.9249047195277803
# mixed-NZ: 0.7127342580411943
# mixed-UK: 0.9484437531327202
# mixed-US: 0.9274150577128727
# CA-AU: 0.879253240933019
# CA-NZ: 0.6196873855315687
# CA-UK: 0.9251674140054204
# CA-US: 0.8962447550823417
# AU-NZ: 0.7141113932563701
# AU-UK: 0.9104817248611266
# AU-US: 0.9217575707567861
# NZ-UK: 0.6748726326898046
# NZ-US: 0.7107087236930216
# UK-US: 0.9586596314269293

# %%
print("base-mixed:",distance_correlation(mat[:,0],mat[:,1]))
print("base-CA:",distance_correlation(mat[:,0],mat[:,2]))
print("base-AU:",distance_correlation(mat[:,0],mat[:,3]))
print("base-NZ:",distance_correlation(mat[:,0],mat[:,4]))
print("base-UK:",distance_correlation(mat[:,0],mat[:,5]))
print("base-US",distance_correlation(mat[:,0],mat[:,6]))
print("base-ZA:",distance_correlation(mat[:,0],mat[:,7]))
# Out:
# base-mixed: 0.39330877782981755
# base-CA: 0.3795731073091994
# base-AU: 0.36334453034975744
# base-NZ: 0.348324929204731
# base-UK: 0.3554600153847539
# base-US 0.3803611706470961
# base-ZA: 0.3145911073000016

# %% [markdown]
# AUC scores

# %%
import seaborn as sns
from scipy.spatial.distance import correlation
all_df = pd.DataFrame()
mat = np.zeros((25,8))
for i in range(30):
  filename = "za-new3-1_"+str(i+1)+"-auc.csv"
  nat_df1 = pd.read_csv(filename)
  nat_df1 = nat_df1.drop(nat_df1.columns[0], axis = 1) #drop the column of index
  m = nat_df1.to_numpy()
  #print(m)
  mat = mat + m
  #print(mat)

mat = mat/30
print("ZA-mixed:",distance_correlation(mat[:,7],mat[:,1]))
print("ZA-CA:",distance_correlation(mat[:,7],mat[:,2]))
print("ZA-AU:",distance_correlation(mat[:,7],mat[:,3]))
print("ZA-NZ:",distance_correlation(mat[:,7],mat[:,4]))
print("ZA-UK:",distance_correlation(mat[:,7],mat[:,5]))
print("ZA-US:",distance_correlation(mat[:,7],mat[:,6]))
print("mixed-CA:",distance_correlation(mat[:,1],mat[:,2]))
print("mixed-AU:",distance_correlation(mat[:,1],mat[:,3]))
print("mixed-NZ:",distance_correlation(mat[:,1],mat[:,4]))
print("mixed-UK:",distance_correlation(mat[:,1],mat[:,5]))
print("mixed-US:",distance_correlation(mat[:,1],mat[:,6]))
print("CA-AU:",distance_correlation(mat[:,2],mat[:,3]))
print("CA-NZ:",distance_correlation(mat[:,2],mat[:,4]))
print("CA-UK:",distance_correlation(mat[:,2],mat[:,5]))
print("CA-US:",distance_correlation(mat[:,2],mat[:,6]))
print("AU-NZ:",distance_correlation(mat[:,3],mat[:,4]))
print("AU-UK:",distance_correlation(mat[:,3],mat[:,5]))
print("AU-US:",distance_correlation(mat[:,3],mat[:,6]))
print("NZ-UK:",distance_correlation(mat[:,4],mat[:,5]))
print("NZ-US:",distance_correlation(mat[:,4],mat[:,6]))
print("UK-US:",distance_correlation(mat[:,5],mat[:,6]))
# Out:
# ZA-mixed: 0.6313718538160868
# ZA-CA: 0.6234336440400996
# ZA-AU: 0.6609765255169855
# ZA-NZ: 0.43727659058852647
# ZA-UK: 0.7276253809478238
# ZA-US: 0.7021677006778128
# mixed-CA: 0.9361169211623189
# mixed-AU: 0.8892275395799013
# mixed-NZ: 0.521320320923328
# mixed-UK: 0.9089995155680409
# mixed-US: 0.9213277723515775
# CA-AU: 0.8761028461166259
# CA-NZ: 0.48133728324163233
# CA-UK: 0.9077682676074246
# CA-US: 0.8657236730139812
# AU-NZ: 0.48426105308350825
# AU-UK: 0.9129262902415943
# AU-US: 0.8636995755879983
# NZ-UK: 0.5200998291264078
# NZ-US: 0.6370269675597091
# UK-US: 0.891527995074299

# %%
print("base-mixed:",distance_correlation(mat[:,0],mat[:,1]))
print("base-CA:",distance_correlation(mat[:,0],mat[:,2]))
print("base-AU:",distance_correlation(mat[:,0],mat[:,3]))
print("base-NZ:",distance_correlation(mat[:,0],mat[:,4]))
print("base-UK:",distance_correlation(mat[:,0],mat[:,5]))
print("base-US",distance_correlation(mat[:,0],mat[:,6]))
print("base-ZA:",distance_correlation(mat[:,0],mat[:,7]))
# Out:
# base-mixed: 0.3414370189488927
# base-CA: 0.3369046523630908
# base-AU: 0.37812651183870577
# base-NZ: 0.25029376733671393
# base-UK: 0.3898161365394681
# base-US 0.3207856054137969
# base-ZA: 0.2978103815240549

# %% [markdown]
# Accuracy scores

# %%
import seaborn as sns
from scipy.spatial.distance import correlation
all_df = pd.DataFrame()
mat = np.zeros((25,8))
#for i in range(30):
filename = "za-mean-30-accuracy.csv"
nat_df1 = pd.read_csv(filename)
nat_df1 = nat_df1.drop(nat_df1.columns[0], axis = 1) #drop the column of index
mat = nat_df1.to_numpy()
  #print(m)
  #mat = mat + m
  #print(mat)

#mat = mat/30
print("ZA-mixed:",distance_correlation(mat[:,7],mat[:,1]))
print("ZA-CA:",distance_correlation(mat[:,7],mat[:,2]))
print("ZA-AU:",distance_correlation(mat[:,7],mat[:,3]))
print("ZA-NZ:",distance_correlation(mat[:,7],mat[:,4]))
print("ZA-UK:",distance_correlation(mat[:,7],mat[:,5]))
print("ZA-US:",distance_correlation(mat[:,7],mat[:,6]))
print("mixed-CA:",distance_correlation(mat[:,1],mat[:,2]))
print("mixed-AU:",distance_correlation(mat[:,1],mat[:,3]))
print("mixed-NZ:",distance_correlation(mat[:,1],mat[:,4]))
print("mixed-UK:",distance_correlation(mat[:,1],mat[:,5]))
print("mixed-US:",distance_correlation(mat[:,1],mat[:,6]))
print("CA-AU:",distance_correlation(mat[:,2],mat[:,3]))
print("CA-NZ:",distance_correlation(mat[:,2],mat[:,4]))
print("CA-UK:",distance_correlation(mat[:,2],mat[:,5]))
print("CA-US:",distance_correlation(mat[:,2],mat[:,6]))
print("AU-NZ:",distance_correlation(mat[:,3],mat[:,4]))
print("AU-UK:",distance_correlation(mat[:,3],mat[:,5]))
print("AU-US:",distance_correlation(mat[:,3],mat[:,6]))
print("NZ-UK:",distance_correlation(mat[:,4],mat[:,5]))
print("NZ-US:",distance_correlation(mat[:,4],mat[:,6]))
print("UK-US:",distance_correlation(mat[:,5],mat[:,6]))
# Out:
# ZA-mixed: 0.33996070303072984
# ZA-CA: 0.41142039605751896
# ZA-AU: 0.5125445798060162
# ZA-NZ: 0.3043512756100998
# ZA-UK: 0.32604257623327987
# ZA-US: 0.5025822113735198
# mixed-CA: 0.7324533471168736
# mixed-AU: 0.6173777920133702
# mixed-NZ: 0.3882214292814176
# mixed-UK: 0.8930732935140584
# mixed-US: 0.628240905982706
# CA-AU: 0.5687756511908236
# CA-NZ: 0.31837113555988694
# CA-UK: 0.7463490087912409
# CA-US: 0.5570066586173832
# AU-NZ: 0.25374129459896605
# AU-UK: 0.6367987966025549
# AU-US: 0.7304419474960225
# NZ-UK: 0.35178556957304435
# NZ-US: 0.21402584087485133
# UK-US: 0.656876728201958

# %%
print("base-mixed:",distance_correlation(mat[:,0],mat[:,1]))
print("base-CA:",distance_correlation(mat[:,0],mat[:,2]))
print("base-AU:",distance_correlation(mat[:,0],mat[:,3]))
print("base-NZ:",distance_correlation(mat[:,0],mat[:,4]))
print("base-UK:",distance_correlation(mat[:,0],mat[:,5]))
print("base-US",distance_correlation(mat[:,0],mat[:,6]))
print("base-ZA:",distance_correlation(mat[:,0],mat[:,7]))
# Out:
# base-mixed: 0.3633349163826401
# base-CA: 0.3299355329411382
# base-AU: 0.335237278522346
# base-NZ: 0.23073801246925632
# base-UK: 0.410613160047413
# base-US 0.30625218249591984
# base-ZA: 0.2798226406212035
