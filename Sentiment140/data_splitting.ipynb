# %% [markdown]
# To save the time of searching corresponding country code tag, we split the data by regions

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

# %%
import pandas as pd
full = pd.read_csv("/content/gdrive/My Drive/sst2/rep/50K-1/twitter140.csv", encoding='latin-1',dtype = str)
text_list = full.iloc[:,5]
lab_list = full.iloc[:,0]
full.columns = ["label", "id", "date", "flag", "user", "text"]

vdata = pd.read_csv("countryInfo50k-100k.csv")
vdata1 = pd.read_csv('/content/gdrive/My Drive/sst2/rep/50K-1/countryInfo0-50k.csv') #Need to check the full data version
vdata = pd.concat([vdata, vdata1])
can_df = vdata[vdata["country"] == 'ca']
#can_df = balance(can_df)
ca_ids = can_df["id"]
ca_inds =[full[full["id"]==str(i)].index[0] for i in ca_ids]
#ca_inds = can_df["index"].tolist()
ca_text =[text_list[i] for i in ca_inds]
ca_lab =[lab_list[n] for n in ca_inds]

import re
ca_text_clean = [' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",t).split()) for t in ca_text]
#ca_text_clean, ca_lab = balance(ca_text_clean, ca_lab)

ca_df1 = pd.DataFrame({"text": ca_text_clean, "labels": ca_lab})
ca_df1.to_csv("/content/gdrive/My Drive/new results/ca.csv")

au_df = vdata[vdata["country"] == 'au']
#au_df = balance(au_df)
#au_inds = au_df["index"].tolist()
au_ids = au_df["id"]
au_inds =[full[full["id"]==str(i)].index[0] for i in au_ids]
au_text =[text_list[i] for i in au_inds]
au_text_clean = [' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",t).split()) for t in au_text]
au_lab =[lab_list[n] for n in au_inds]
#au_text_clean, au_lab = balance(au_text_clean, au_lab)
au_df1 = pd.DataFrame({"text": au_text_clean, "labels": au_lab})
au_df1.to_csv("/content/gdrive/My Drive/new results/au.csv")

nz_df = vdata[vdata["country"] == 'nz']
#nz_df = balance(nz_df)
#nz_inds = nz_df["index"].tolist()
nz_ids = nz_df["id"]
nz_inds =[full[full["id"]==str(i)].index[0] for i in nz_ids]
nz_text =[text_list[i] for i in nz_inds]
nz_text_clean = [' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",t).split()) for t in nz_text]
nz_lab =[lab_list[n] for n in nz_inds]
#nz_text_clean, nz_lab = balance(nz_text_clean, nz_lab)
nz_df1 = pd.DataFrame({"text": nz_text_clean, "labels": nz_lab})
nz_df1.to_csv("/content/gdrive/My Drive/new results/nz.csv")

uk_df = vdata[vdata["country"] == 'gb']
#uk_df = balance(uk_df)
#uk_inds = uk_df["index"].tolist()
uk_ids = uk_df["id"]
uk_inds =[full[full["id"]==str(i)].index[0] for i in uk_ids]
uk_text =[text_list[i] for i in uk_inds]
uk_text_clean = [' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",t).split()) for t in uk_text]
uk_lab =[lab_list[n] for n in uk_inds]
#uk_text_clean, uk_lab = balance(uk_text_clean, uk_lab)
uk_df1 = pd.DataFrame({"text": uk_text_clean, "labels": uk_lab})
uk_df1.to_csv("/content/gdrive/My Drive/new results/uk.csv")


us_df = vdata[vdata["country"] == 'us']
#us_df = balance(us_df)
#us_inds = us_df["index"].tolist()
us_ids = us_df["id"]
us_inds =[full[full["id"]==str(i)].index[0] for i in us_ids]
us_text =[text_list[i] for i in us_inds]
us_text_clean = [' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",t).split()) for t in us_text]
us_lab =[lab_list[n] for n in us_inds]
#us_text_clean, us_lab = balance(us_text_clean, us_lab)
us_df1 = pd.DataFrame({"text": us_text_clean, "labels": us_lab})
us_df1.to_csv("/content/gdrive/My Drive/new results/us.csv")

za_df = vdata[vdata["country"] == 'za']
#us_df = balance(us_df)
#us_inds = us_df["index"].tolist()
za_ids = za_df["id"]
za_inds =[full[full["id"]==str(i)].index[0] for i in za_ids]
za_text =[text_list[i] for i in za_inds]
za_text_clean = [' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",t).split()) for t in za_text]
za_lab =[lab_list[n] for n in za_inds]
#us_text_clean, us_lab = balance(us_text_clean, us_lab)
za_df1 = pd.DataFrame({"text": za_text_clean, "labels": za_lab})
za_df1.to_csv("/content/gdrive/My Drive/new results/za.csv")
