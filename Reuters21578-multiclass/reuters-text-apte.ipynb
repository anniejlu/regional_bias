# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# %cd "/content/gdrive/My Drive/reuters/hedwig-master/hedwig-data/datasets/Reuters"
# Out:
# /content/gdrive/My Drive/reuters/hedwig-master/hedwig-data/datasets/Reuters

# %%
# !pip install datasets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 8.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 12.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 15.3 MB/s eta 0:00:00
# ...

# %%
from textwrap import dedent

import datasets

# %%
_DESCRIPTION = """\
The Reuters-21578 dataset  is one of the most widely used data collections for text
categorization research. It is collected from the Reuters financial newswire service in 1987.
"""

# %%
from datasets import load_dataset_builder
#ds_builder = load_dataset_builder("reuters21578", "ModLewis")

# %%
from datasets import load_dataset
dataset = load_dataset("reuters21578", "ModApte")
# Out:
# ...
# Generating unused split:   0%|          | 0/722 [00:00<?, ? examples/s]

# %%
dataset
# Out:
# DatasetDict({
#     test: Dataset({
#         features: ['text', 'text_type', 'topics', 'lewis_split', 'cgis_split', 'old_id', 'new_id', 'places', 'people', 'orgs', 'exchanges', 'date', 'title'],
#         num_rows: 6188
#     })
#     train: Dataset({
#         features: ['text', 'text_type', 'topics', 'lewis_split', 'cgis_split', 'old_id', 'new_id', 'places', 'people', 'orgs', 'exchanges', 'date', 'title'],
#         num_rows: 13625
#     })
#     unused: Dataset({
#         features: ['text', 'text_type', 'topics', 'lewis_split', 'cgis_split', 'old_id', 'new_id', 'places', 'people', 'orgs', 'exchanges', 'date', 'title'],
#         num_rows: 722
#     })
# })

# %%
texts = []
places = []
topics = []
for i in dataset["train"]:
  pl = i["places"]
  tps = i["topics"]
  if tps == []:
    print("NULL")
  else:
    if len(pl) == 1 :
      if (pl[0] == "canada") or (pl[0] == "australia") or (pl[0] == "new-zealand") or (pl[0] == "uk") or (pl[0] == "usa") or (pl[0] == "south-africa"):
        places.append(pl[0])
        texts.append(i["text"])
        topics.append(i["topics"])
# Out:
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# ...

# %%
len(places)
# Out:
# 5056

# %%
len(texts)
# Out:
# 5056

# %%
import pandas as pd
df = pd.DataFrame({"text":texts, "topics":topics, "place": places})

# %%
len(df[df["place"]=="canada"])
# Out:
# 396

# %%
len(df[df["place"]=="australia"])
# Out:
# 98

# %%
len(df[df["place"]=="new-zealand"])
# Out:
# 38

# %%
len(df[df["place"]=="uk"])
# Out:
# 390

# %%
len(df[df["place"]=="usa"])
# Out:
# 4100

# %%
len(df[df["place"]=="south-africa"])
# Out:
# 34

# %%
train_text = []
train_topic = []
places3=[]
for i in dataset["train"]:
  tps = i["topics"]
  pl = i["places"]
  if tps == []:
    print("NULL")
  else:
    train_text.append(i["text"])
    train_topic.append(i["topics"])
    if len(pl) == 1 :
      if (pl[0] == "canada") or (pl[0] == "australia") or (pl[0] == "new-zealand") or (pl[0] == "uk") or (pl[0] == "usa") or (pl[0] == "south-africa"):
        places3.append(pl[0])
# Out:
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# ...

# %%
len(train_text)
# Out:
# 7775

# %%
sum([i=="usa" for i in places3])
# Out:
# 4100

# %%
sum([i=="canada" for i in places3])
# Out:
# 396

# %%
sum([i=="uk" for i in places3])
# Out:
# 390

# %%
sum([i=="australia" for i in places3])
# Out:
# 98

# %%
train_text = []
train_topic = []
for i in dataset["train"]:
  tps = i["topics"]
  #pl = i["places"]
  if tps == []:
    print("NULL")
  else:
  #if len(pl) == 1 :
    #if (pl[0] == "canada") or (pl[0] == "australia") or (pl[0] == "new-zealand") or (pl[0] == "uk") or (pl[0] == "usa") or (pl[0] == "south-africa"):
      #places3.append(pl[0])
    train_text.append(i["text"])
    train_topic.append(i["topics"])
# Out:
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# ...

# %%
from sklearn.preprocessing import MultiLabelBinarizer
mlb2 = MultiLabelBinarizer()
mlb2.fit(train_topic)
#a = mlb.transform(df3['topics'])
a = mlb2.transform(train_topic)

import numpy as np

b = a.astype("str"). tolist()
c = ["".join(d) for d in b]

# %%
train_text = [x.replace("\n", "") for x in train_text]
train_text = [x.replace("    ", " ") for x in train_text]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(train_text, train_label, test_size=0.1)

# %%
df = pd.DataFrame({"label":y_train, "text": X_train})
df.to_csv('train.tsv', sep="\t", index = False)

# %%
df = pd.DataFrame({"label":y_test, "text": X_test})
df.to_csv('dev.tsv', sep="\t", index = False)

# %%
test_text = []
test_topic = []
for i in dataset["test"]:
  tps = i["topics"]
  #pl = i["places"]
  if tps == []:
    print("NULL")
  else:
  #if len(pl) == 1 :
    #if (pl[0] == "canada") or (pl[0] == "australia") or (pl[0] == "new-zealand") or (pl[0] == "uk") or (pl[0] == "usa") or (pl[0] == "south-africa"):
      #places3.append(pl[0])
    test_text.append(i["text"])
    test_topic.append(i["topics"])
# Out:
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# ...

# %%
len(test_text)
# Out:
# 3019

# %%
a = mlb2.transform(test_topic)

import numpy as np

b = a.astype("str"). tolist()
c = ["".join(d) for d in b]
test_label = c
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['cottonseed', 'f-cattle', 'sfr'] will be ignored
#   warnings.warn(

# %%
len(train_text)
# Out:
# 7775

# %%
len(mlb2.classes_)
# Out:
# 115

# %%
test_text = [x.replace("\n", "") for x in test_text]
test_text = [x.replace("    ", " ") for x in test_text]

# %%
import pandas as pd
df = pd.DataFrame({"label":test_label, "text": test_text})
df.to_csv('test.tsv', sep="\t", index = False)

# %%
texts3 = []
places3 = []
topics3 = []
for i in dataset["test"]:
  pl = i["places"]
  tps = i["topics"]
  if tps == []:
    print("NULL")
  else:
    if len(pl) == 1 :
      if (pl[0] == "canada") or (pl[0] == "australia") or (pl[0] == "new-zealand") or (pl[0] == "uk") or (pl[0] == "usa") or (pl[0] == "south-africa"):
        places3.append(pl[0])
        texts3.append(i["text"])
        topics3.append(i["topics"])

# %%
df3["text"] = [x.replace("\n", "") for x in df3["text"]]
df3["text"] = [x.replace("    ", " ") for x in df3["text"]]

# %%
from sklearn.preprocessing import MultiLabelBinarizer
#mlb = MultiLabelBinarizer()
#mlb.fit(dataset["train"]["topics"])
a = mlb2.transform(df3['topics'])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['f-cattle'] will be ignored
#   warnings.warn(

# %%
import numpy as np

b = a.astype("str"). tolist()
c = ["".join(d) for d in b]

# %%
df3["label"] = c

# %%
can_df = df3[df3["place"]=="canada"]
aus_df = df3[df3["place"]=="australia"]
uk_df = df3[df3["place"]=="uk"]
us_df = df3[df3["place"]=="usa"]

# %%
d = pd.DataFrame(can_df["label"])
d["text"] = can_df["text"]
d.to_csv('ca.tsv', sep="\t", index = False)

# %%
d = pd.DataFrame(aus_df["label"])
d["text"] = aus_df["text"]
d.to_csv('au.tsv', sep="\t", index = False)

# %%
d = pd.DataFrame(uk_df["label"])
d["text"] = uk_df["text"]
d.to_csv('uk.tsv', sep="\t", index = False)

# %%
d = pd.DataFrame(us_df["label"])
d["text"] = us_df["text"]
d.to_csv('us.tsv', sep="\t", index = False)

# %%
len(df3[df3["place"]=="canada"])
# Out:
# 123

# %%
len(df3[df3["place"]=="australia"])
# Out:
# 35

# %%
len(df3[df3["place"]=="new-zealand"])
# Out:
# 10

# %%
len(df3[df3["place"]=="uk"])
# Out:
# 106

# %%
len(df3[df3["place"]=="usa"])
# Out:
# 1694

# %%
len(df3[df3["place"]=="south-africa"])
# Out:
# 9

# %%
texts4 = []
places4= []
topics4 = []
for i in dataset["test"]:
  pl = i["places"]
  ts = i["text"]
  tps = i["topics"]
  #if len(pl) == 1 :
  if tps == []:
    print("NULL")
  else:
    if ("canada" in pl) or ("australia" in pl) or ("new-zealand" in pl) or ("uk" in pl) or ("usa" in pl) or ("south-africa" in pl):
    #print(pl)
    #for p in pl:
      #print(p)
      places4.append(pl)
      texts4.append(ts)
      topics4.append(tps)
# Out:
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# NULL
# ...

# %%
len(places4)
# Out:
# 2312

# %%
import pandas as pd
df4 = pd.DataFrame({"text":texts4, "topics":topics4, "place": places4})

# %%
df4["text"] = [x.replace("\n", "") for x in df4["text"]]
df4["text"] = [x.replace("    ", " ") for x in df4["text"]]

# %%
from sklearn.preprocessing import MultiLabelBinarizer
#from sklearn.preprocessing import MultiLabelBinarizer
#mlb = MultiLabelBinarizer()
#mlb.fit(dataset["train"]["topics"])
a = mlb2.transform(df4['topics'])

b = a.astype("str"). tolist()
c = ["".join(d) for d in b]
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['f-cattle'] will be ignored
#   warnings.warn(

# %%
df4["label"] = c

# %%
d = pd.DataFrame(df4["label"])
d["text"] = df4["text"]
d.to_csv('mtp0.tsv', sep="\t", index = False)

# %%
len(df4[df4["place"]=="canada"])
# Out:
# 182

# %%
len(df4[df4["place"]=="australia"])
# Out:
# 48

# %%
len(df4[df4["place"]=="new-zealand"])
# Out:
# 16

# %%
len(df4[df4["place"]=="uk"])
# Out:
# 230

# %%
len(df4[df4["place"]=="usa"])
# Out:
# 2112

# %%
len(df4[df4["place"]=="south-africa"])
# Out:
# 17
