# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# %cd "/content/gdrive/My Drive/reuters/hedwig-master/hedwig-master"
# Out:
# /content/gdrive/My Drive/reuters/hedwig-master/hedwig-master

# %%
#!pip install pytorch=0.4.1 cuda92 -c pytorch
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'pytorch'

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 14.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 9.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 40.3 MB/s eta 0:00:00
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
import torch

# %%
# %ls
# Out:
# common/    hedwig/          __init__.py  model_checkpoints/  requirements.txt  utils/
# datasets/  hedwig-data/     job_output/  models/             setup.py
# docs/      hedwig-data.zip  LICENSE      README.md           tasks/

# %%
# %cd "hedwig-data"
# Out:
# /content/gdrive/MyDrive/reuters/hedwig-master/hedwig-master/hedwig-data

# %%
# %ls
# Out:
# datasets/  embeddings/  models/

# %%
# !pip uninstall transformers
# Out:
# Found existing installation: transformers 4.35.2
# Uninstalling transformers-4.35.2:
#   Would remove:
#     /usr/local/bin/transformers-cli
#     /usr/local/lib/python3.10/dist-packages/transformers-4.35.2.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/transformers/*
# Proceed (Y/n)? Y
#   Successfully uninstalled transformers-4.35.2

# %%
# !pip install transformers==2.1.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.7/311.7 kB 5.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 15.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 34.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 70.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 102.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 12.3 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/castorini/hedwig.git
# Out:
# Cloning into 'hedwig'...
# remote: Enumerating objects: 2272, done.
# remote: Counting objects: 100% (308/308), done.
# remote: Compressing objects: 100% (107/107), done.
# remote: Total 2272 (delta 215), reused 251 (delta 199), pack-reused 1964
# Receiving objects: 100% (2272/2272), 23.91 MiB | 13.78 MiB/s, done.
# Resolving deltas: 100% (1335/1335), done.

# %%
# !git clone https://git.uwaterloo.ca/jimmylin/hedwig-data.git
# Out:
# Cloning into 'hedwig-data'...
# remote: Enumerating objects: 70, done.
# remote: Total 70 (delta 0), reused 0 (delta 0), pack-reused 70
# Receiving objects: 100% (70/70), 5.45 GiB | 15.65 MiB/s, done.
# Resolving deltas: 100% (5/5), done.
# Updating files: 100% (20/20), done.

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# %cd "/content/gdrive/My Drive/reuters"
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/reuters

# %%
region = ["Test", "CA", "AU","UK","US", "MTP"]
accuracy = [0.7612, 0.7805, 0.8571, 0.6792, 0.9115, 0.6893]
precision = [0.9154,0.9015,0.8864,0.8584,0.9635,0.8468]
recall = [0.7714, 0.8207, 0.9070,0.7578,0.9013,0.7664]
f1 = [0.8372,0.8592,0.8966,0.8050,0.9314,0.8046]
import pandas as pd
df = pd.DataFrame({"region": region, "accuracy":accuracy, "precision":precision,"recall":recall, "f1":f1})
df.to_csv("reuters-results.csv", index = False)

# %%
# !python -m models.bert --dataset Reuters --model bert-base-uncased --max-seq-length 256 --batch-size 16 --lr 2e-5 --epochs 30 --trained-model model_checkpoints/bert/Reuters/2023-10-25_01-37-02.pt #best accuracy model

## you can either run it with the best model I trained or just train it with the parameter before "--trained-model  model_checkpoints/bert/Reuters/2023-10-25_01-37-02.pt"
# Out:
# 2023-11-17 08:17:21.135823: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-17 08:17:21.135871: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-17 08:17:21.135898: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-17 08:17:21.143600: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python -m models.bert --dataset Reuters --model bert-base-uncased --max-seq-length 256 --batch-size 16 --lr 2e-5 --epochs 50 ##reduce 2000 data in training
# Out:
# Streaming output truncated to the last 5000 lines.
# Training:  93% 301/325 [01:13<00:05,  4.10it/s]
# Training:  93% 302/325 [01:13<00:05,  4.11it/s]
# Training:  93% 303/325 [01:13<00:05,  4.13it/s]
# Training:  94% 304/325 [01:13<00:05,  4.14it/s]
# Training:  94% 305/325 [01:13<00:04,  4.15it/s]
# Training:  94% 306/325 [01:14<00:04,  4.16it/s]
# Training:  94% 307/325 [01:14<00:04,  4.16it/s]
# Training:  95% 308/325 [01:14<00:04,  4.13it/s]
# Training:  95% 309/325 [01:14<00:03,  4.14it/s]
# Training:  95% 310/325 [01:15<00:03,  4.11it/s]
# Training:  96% 311/325 [01:15<00:03,  4.12it/s]
# Training:  96% 312/325 [01:15<00:03,  4.14it/s]
# Training:  96% 313/325 [01:15<00:02,  4.12it/s]
# Training:  97% 314/325 [01:16<00:02,  4.13it/s]
# Training:  97% 315/325 [01:16<00:02,  4.10it/s]
# Training:  97% 316/325 [01:16<00:02,  4.12it/s]
# Training:  98% 317/325 [01:16<00:01,  4.14it/s]
# Training:  98% 318/325 [01:17<00:01,  4.14it/s]
# ...

# %%
# !python -m models.bert --dataset Reuters --model bert-base-uncased --max-seq-length 256 --batch-size 16 --lr 3e-5 --epochs 75 ##1000 out of 4000 us data in training
# Out:
# 2023-11-18 04:12:04.618973: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-18 04:12:04.619035: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-18 04:12:04.619061: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-18 04:12:04.627088: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python -m models.bert --dataset Reuters --model bert-base-uncased --max-seq-length 256 --batch-size 16 --lr 2e-5 --epochs 50 ##2000 out of 4000 us data in training
# Out:
# Streaming output truncated to the last 5000 lines.
# Training:  93% 301/325 [01:11<00:05,  4.19it/s]
# Training:  93% 302/325 [01:12<00:05,  4.20it/s]
# Training:  93% 303/325 [01:12<00:05,  4.19it/s]
# Training:  94% 304/325 [01:12<00:05,  4.19it/s]
# Training:  94% 305/325 [01:12<00:04,  4.19it/s]
# Training:  94% 306/325 [01:12<00:04,  4.19it/s]
# Training:  94% 307/325 [01:13<00:04,  4.19it/s]
# Training:  95% 308/325 [01:13<00:04,  4.19it/s]
# Training:  95% 309/325 [01:13<00:03,  4.19it/s]
# Training:  95% 310/325 [01:13<00:03,  4.19it/s]
# Training:  96% 311/325 [01:14<00:03,  4.20it/s]
# Training:  96% 312/325 [01:14<00:03,  4.19it/s]
# Training:  96% 313/325 [01:14<00:02,  4.20it/s]
# Training:  97% 314/325 [01:14<00:02,  4.20it/s]
# Training:  97% 315/325 [01:15<00:02,  4.21it/s]
# Training:  97% 316/325 [01:15<00:02,  4.20it/s]
# Training:  98% 317/325 [01:15<00:01,  4.19it/s]
# Training:  98% 318/325 [01:15<00:01,  4.20it/s]
# ...
